# %%
from model import *

# %% [markdown]
# # Padam, Resnet, p = 1/4

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/4
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar10_p4'

resnet_padam_cifar10_p4 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar10_p4_train_loss, resnet_padam_cifar10_p4_val_error = resnet_padam_cifar10_p4.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.822256 | Validation Accuracy: 43.5% | Time elapsed: 36.17s
# Epoch 2 | Training Loss (Avg): 1.411512 | Validation Accuracy: 49.94% | Time elapsed: 36.22s
# Epoch 3 | Training Loss (Avg): 1.286003 | Validation Accuracy: 56.24% | Time elapsed: 35.45s
# Epoch 4 | Training Loss (Avg): 1.229040 | Validation Accuracy: 58.66% | Time elapsed: 35.37s
# Epoch 5 | Training Loss (Avg): 1.186500 | Validation Accuracy: 57.84% | Time elapsed: 35.30s
# Epoch 6 | Training Loss (Avg): 1.166579 | Validation Accuracy: 63.62% | Time elapsed: 35.15s
# Epoch 7 | Training Loss (Avg): 1.152947 | Validation Accuracy: 57.8% | Time elapsed: 34.69s
# Epoch 8 | Training Loss (Avg): 1.142639 | Validation Accuracy: 56.46% | Time elapsed: 35.06s
# Epoch 9 | Training Loss (Avg): 1.123968 | Validation Accuracy: 59.24% | Time elapsed: 35.22s
# Epoch 10 | Training Loss (Avg): 1.118976 | Validation Accuracy: 54.56% | Time elapsed: 34.51s
# ...

# %%
resnet_padam_cifar10_p4.test()
# Out:
# Accuracy of the model on test images: 74.0%

# %% [markdown]
# # Padam, Resnet, p = 1/8

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar10_p8'

resnet_padam_cifar10_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar10_p8_train_loss, resnet_padam_cifar10_p8_val_error = resnet_padam_cifar10_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.705207 | Validation Accuracy: 56.62% | Time elapsed: 37.03s
# Epoch 2 | Training Loss (Avg): 1.183470 | Validation Accuracy: 58.2% | Time elapsed: 36.36s
# Epoch 3 | Training Loss (Avg): 0.992523 | Validation Accuracy: 68.24% | Time elapsed: 36.07s
# Epoch 4 | Training Loss (Avg): 0.877990 | Validation Accuracy: 69.54% | Time elapsed: 35.95s
# Epoch 5 | Training Loss (Avg): 0.810375 | Validation Accuracy: 72.16% | Time elapsed: 36.25s
# Epoch 6 | Training Loss (Avg): 0.753294 | Validation Accuracy: 70.52% | Time elapsed: 36.12s
# Epoch 7 | Training Loss (Avg): 0.721294 | Validation Accuracy: 73.78% | Time elapsed: 36.00s
# Epoch 8 | Training Loss (Avg): 0.692580 | Validation Accuracy: 73.18% | Time elapsed: 36.14s
# Epoch 9 | Training Loss (Avg): 0.657887 | Validation Accuracy: 73.46% | Time elapsed: 36.32s
# Epoch 10 | Training Loss (Avg): 0.643955 | Validation Accuracy: 71.74% | Time elapsed: 36.38s
# ...

# %%
resnet_padam_cifar10_p8.test()
# Out:
# Accuracy of the model on test images: 79.0%

# %% [markdown]
# # Padam, Resnet, p = 1/16

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/16
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar10_p16'

resnet_padam_cifar10_p16 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar10_p16_train_loss, resnet_padam_cifar10_p16_val_error = resnet_padam_cifar10_p16.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.648159 | Validation Accuracy: 56.94% | Time elapsed: 37.19s
# Epoch 2 | Training Loss (Avg): 1.144639 | Validation Accuracy: 65.96% | Time elapsed: 35.55s
# Epoch 3 | Training Loss (Avg): 0.930374 | Validation Accuracy: 69.98% | Time elapsed: 35.86s
# Epoch 4 | Training Loss (Avg): 0.806640 | Validation Accuracy: 69.1% | Time elapsed: 36.12s
# Epoch 5 | Training Loss (Avg): 0.718620 | Validation Accuracy: 71.32% | Time elapsed: 35.70s
# Epoch 6 | Training Loss (Avg): 0.646732 | Validation Accuracy: 73.24% | Time elapsed: 35.64s
# Epoch 7 | Training Loss (Avg): 0.594684 | Validation Accuracy: 72.34% | Time elapsed: 35.90s
# Epoch 8 | Training Loss (Avg): 0.543249 | Validation Accuracy: 72.14% | Time elapsed: 35.78s
# Epoch 9 | Training Loss (Avg): 0.507379 | Validation Accuracy: 72.4% | Time elapsed: 36.21s
# Epoch 10 | Training Loss (Avg): 0.478779 | Validation Accuracy: 73.82% | Time elapsed: 36.25s
# ...

# %%
resnet_padam_cifar10_p16.test()
# Out:
# Accuracy of the model on test images: 79.0%

# %% [markdown]
# # Padam, Resnet, p = 1/2

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/2
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar10_p2'

resnet_padam_cifar10_p2 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar10_p2_train_loss, resnet_padam_cifar10_p2_val_error = resnet_padam_cifar10_p2.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.167218 | Validation Accuracy: 18.12% | Time elapsed: 35.63s
# Epoch 2 | Training Loss (Avg): 2.009764 | Validation Accuracy: 15.58% | Time elapsed: 34.22s
# Epoch 3 | Training Loss (Avg): 2.065724 | Validation Accuracy: 19.5% | Time elapsed: 34.25s
# Epoch 4 | Training Loss (Avg): 2.060433 | Validation Accuracy: 14.78% | Time elapsed: 34.52s
# Epoch 5 | Training Loss (Avg): 2.034659 | Validation Accuracy: 21.84% | Time elapsed: 34.38s
# Epoch 6 | Training Loss (Avg): 2.020033 | Validation Accuracy: 22.82% | Time elapsed: 34.60s
# Epoch 7 | Training Loss (Avg): 1.990711 | Validation Accuracy: 19.72% | Time elapsed: 34.51s
# Epoch 8 | Training Loss (Avg): 1.979901 | Validation Accuracy: 15.32% | Time elapsed: 34.61s
# Epoch 9 | Training Loss (Avg): 1.973248 | Validation Accuracy: 13.16% | Time elapsed: 34.25s
# Epoch 10 | Training Loss (Avg): 1.989001 | Validation Accuracy: 23.6% | Time elapsed: 34.09s
# ...

# %%
resnet_padam_cifar10_p2.test()
# Out:
# Accuracy of the model on test images: 30.0%

# %% [markdown]
# # Visualizations - Train Loss vs Epoch (Padam, Resnet, for multiple p)

# %%
plt.plot(resnet_padam_cifar10_p2_train_loss, label = 'p=1/2')
plt.plot(resnet_padam_cifar10_p4_train_loss, label = 'p=1/4')
plt.plot(resnet_padam_cifar10_p8_train_loss, label = 'p=1/8')
plt.plot(resnet_padam_cifar10_p16_train_loss, label = 'p=1/16')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Visualizations - Validation Error vs Epoch (Padam, Resnet, for multiple p)

# %%
plt.plot(resnet_padam_cifar10_p2_val_error, label = 'p=1/2')
plt.plot(resnet_padam_cifar10_p4_val_error, label = 'p=1/4')
plt.plot(resnet_padam_cifar10_p8_val_error, label = 'p=1/8')
plt.plot(resnet_padam_cifar10_p16_val_error, label = 'p=1/16')
plt.xlabel("Epochs")
plt.ylabel("Validation Error per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Padam, VGG, p = 1/8

# %%
model_type = 'vgg'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_padam_cifar10_p4'

vgg_padam_cifar10_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_padam_cifar10_p8_train_loss, vgg_padam_cifar10_p8_val_error = vgg_padam_cifar10_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.349474 | Validation Accuracy: 27.94% | Time elapsed: 80.67s
# Epoch 2 | Training Loss (Avg): 1.662082 | Validation Accuracy: 48.3% | Time elapsed: 80.74s
# Epoch 3 | Training Loss (Avg): 1.334469 | Validation Accuracy: 56.42% | Time elapsed: 80.77s
# Epoch 4 | Training Loss (Avg): 1.102949 | Validation Accuracy: 62.64% | Time elapsed: 80.79s
# Epoch 5 | Training Loss (Avg): 0.935101 | Validation Accuracy: 69.0% | Time elapsed: 80.81s
# Epoch 6 | Training Loss (Avg): 0.804693 | Validation Accuracy: 71.4% | Time elapsed: 80.83s
# Epoch 7 | Training Loss (Avg): 0.695198 | Validation Accuracy: 74.64% | Time elapsed: 80.78s
# Epoch 8 | Training Loss (Avg): 0.596061 | Validation Accuracy: 75.74% | Time elapsed: 80.80s
# Epoch 9 | Training Loss (Avg): 0.511391 | Validation Accuracy: 72.56% | Time elapsed: 80.85s
# Epoch 10 | Training Loss (Avg): 0.433378 | Validation Accuracy: 76.2% | Time elapsed: 80.70s
# ...

# %%
vgg_padam_cifar10_p8.test()
# Out:
# Accuracy of the model on test images: 80.0%

# %% [markdown]
# # Padam, WideResnet, p = 1/8

# %%
model_type = 'wideresnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar10'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_padam_cifar10_p4'

wideresnet_padam_cifar10_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_padam_cifar10_p8_train_loss, wideresnet_padam_cifar10_p8_val_error = wideresnet_padam_cifar10_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.015220 | Validation Accuracy: 25.14% | Time elapsed: 192.33s
# Epoch 2 | Training Loss (Avg): 1.992533 | Validation Accuracy: 31.14% | Time elapsed: 192.08s
# Epoch 3 | Training Loss (Avg): 1.746400 | Validation Accuracy: 39.92% | Time elapsed: 192.13s
# Epoch 4 | Training Loss (Avg): 1.633037 | Validation Accuracy: 43.7% | Time elapsed: 191.98s
# Epoch 5 | Training Loss (Avg): 1.557830 | Validation Accuracy: 41.48% | Time elapsed: 192.16s
# Epoch 6 | Training Loss (Avg): 1.539618 | Validation Accuracy: 47.4% | Time elapsed: 192.14s
# Epoch 7 | Training Loss (Avg): 1.450974 | Validation Accuracy: 49.04% | Time elapsed: 192.31s
# Epoch 8 | Training Loss (Avg): 1.402424 | Validation Accuracy: 52.14% | Time elapsed: 192.55s
# Epoch 9 | Training Loss (Avg): 1.341588 | Validation Accuracy: 53.48% | Time elapsed: 192.15s
# Epoch 10 | Training Loss (Avg): 1.297266 | Validation Accuracy: 54.06% | Time elapsed: 191.75s
# ...

# %%
wideresnet_padam_cifar10_p8.test()
# Out:
# Accuracy of the model on test images: 78.0%

# %% [markdown]
# # SGD, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'sgd'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_sgd_cifar10'

resnet_sgd_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_sgd_cifar10_train_loss, resnet_sgd_cifar10_val_error = resnet_sgd_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.149454 | Validation Accuracy: 38.86% | Time elapsed: 30.46s
# Epoch 2 | Training Loss (Avg): 1.586259 | Validation Accuracy: 47.92% | Time elapsed: 30.19s
# Epoch 3 | Training Loss (Avg): 1.382210 | Validation Accuracy: 50.82% | Time elapsed: 30.14s
# Epoch 4 | Training Loss (Avg): 1.237320 | Validation Accuracy: 56.12% | Time elapsed: 30.25s
# Epoch 5 | Training Loss (Avg): 1.108788 | Validation Accuracy: 62.42% | Time elapsed: 30.52s
# Epoch 6 | Training Loss (Avg): 1.021854 | Validation Accuracy: 63.66% | Time elapsed: 30.58s
# Epoch 7 | Training Loss (Avg): 0.926742 | Validation Accuracy: 64.34% | Time elapsed: 30.18s
# Epoch 8 | Training Loss (Avg): 0.841923 | Validation Accuracy: 66.2% | Time elapsed: 30.32s
# Epoch 9 | Training Loss (Avg): 0.786845 | Validation Accuracy: 50.08% | Time elapsed: 30.46s
# Epoch 10 | Training Loss (Avg): 1.418141 | Validation Accuracy: 58.98% | Time elapsed: 30.25s
# ...

# %%
resnet_sgd_cifar10.test()
# Out:
# Accuracy of the model on test images: 73.0%

# %% [markdown]
# # SGD, VGG

# %%
model_type = 'vgg'
optimizer_type = 'sgd'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_sgd_cifar10'

vgg_sgd_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_sgd_cifar10_train_loss, vgg_sgd_cifar10_val_error = vgg_sgd_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.479860 | Validation Accuracy: 10.22% | Time elapsed: 137.68s
# Epoch 2 | Training Loss (Avg): 2.353701 | Validation Accuracy: 9.72% | Time elapsed: 137.46s
# Epoch 3 | Training Loss (Avg): 2.344238 | Validation Accuracy: 9.6% | Time elapsed: 137.47s
# Epoch 4 | Training Loss (Avg): 2.341756 | Validation Accuracy: 9.96% | Time elapsed: 137.49s
# Epoch 5 | Training Loss (Avg): 2.340765 | Validation Accuracy: 9.68% | Time elapsed: 137.48s
# Epoch 6 | Training Loss (Avg): 2.341479 | Validation Accuracy: 9.6% | Time elapsed: 137.43s
# Epoch 7 | Training Loss (Avg): 2.340260 | Validation Accuracy: 10.4% | Time elapsed: 137.46s
# Epoch 8 | Training Loss (Avg): 2.341874 | Validation Accuracy: 9.72% | Time elapsed: 137.48s
# Epoch 9 | Training Loss (Avg): 2.339760 | Validation Accuracy: 9.96% | Time elapsed: 137.46s
# Epoch 10 | Training Loss (Avg): 2.340002 | Validation Accuracy: 9.96% | Time elapsed: 137.46s
# ...

# %%
vgg_sgd_cifar10.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # SGD, WideResnet

# %%
model_type = 'wideresnet'
optimizer_type = 'sgd'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_sgd_cifar10'

wideresnet_sgd_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_sgd_cifar10_train_loss, wideresnet_sgd_cifar10_val_error = wideresnet_sgd_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.190268 | Validation Accuracy: 19.58% | Time elapsed: 161.88s
# Epoch 2 | Training Loss (Avg): 2.047179 | Validation Accuracy: 27.86% | Time elapsed: 163.09s
# Epoch 3 | Training Loss (Avg): 1.836732 | Validation Accuracy: 37.44% | Time elapsed: 162.78s
# Epoch 4 | Training Loss (Avg): 1.726516 | Validation Accuracy: 39.62% | Time elapsed: 162.89s
# Epoch 5 | Training Loss (Avg): 1.645113 | Validation Accuracy: 44.36% | Time elapsed: 163.11s
# Epoch 6 | Training Loss (Avg): 1.567278 | Validation Accuracy: 44.64% | Time elapsed: 162.79s
# Epoch 7 | Training Loss (Avg): 1.515440 | Validation Accuracy: 47.8% | Time elapsed: 163.03s
# Epoch 8 | Training Loss (Avg): 1.446485 | Validation Accuracy: 49.54% | Time elapsed: 162.97s
# Epoch 9 | Training Loss (Avg): 1.422572 | Validation Accuracy: 50.7% | Time elapsed: 162.88s
# Epoch 10 | Training Loss (Avg): 1.389446 | Validation Accuracy: 52.14% | Time elapsed: 162.90s
# ...

# %%
wideresnet_sgd_cifar10.test()
# Out:
# Accuracy of the model on test images: 37.0%

# %% [markdown]
# # Adam, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adam_cifar10'

resnet_adam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adam_cifar10_train_loss, resnet_adam_cifar10_val_error = resnet_adam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.230151 | Validation Accuracy: 16.62% | Time elapsed: 34.50s
# Epoch 2 | Training Loss (Avg): 2.018425 | Validation Accuracy: 13.36% | Time elapsed: 34.56s
# Epoch 3 | Training Loss (Avg): 2.064903 | Validation Accuracy: 13.08% | Time elapsed: 34.16s
# Epoch 4 | Training Loss (Avg): 2.144802 | Validation Accuracy: 12.04% | Time elapsed: 34.29s
# Epoch 5 | Training Loss (Avg): 2.154233 | Validation Accuracy: 10.5% | Time elapsed: 34.19s
# Epoch 6 | Training Loss (Avg): 2.198868 | Validation Accuracy: 11.7% | Time elapsed: 34.49s
# Epoch 7 | Training Loss (Avg): 2.237898 | Validation Accuracy: 10.26% | Time elapsed: 34.51s
# Epoch 8 | Training Loss (Avg): 2.229820 | Validation Accuracy: 9.36% | Time elapsed: 34.60s
# Epoch 9 | Training Loss (Avg): 2.213318 | Validation Accuracy: 12.66% | Time elapsed: 34.46s
# Epoch 10 | Training Loss (Avg): 2.211536 | Validation Accuracy: 15.12% | Time elapsed: 34.57s
# ...

# %%
resnet_adam_cifar10.test()
# Out:
# Accuracy of the model on test images: 43.0%

# %% [markdown]
# # Adam, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adam_cifar10'

vgg_adam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adam_cifar10_train_loss, vgg_adam_cifar10_val_error = vgg_adam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.446844 | Validation Accuracy: 10.06% | Time elapsed: 127.59s
# Epoch 2 | Training Loss (Avg): 2.357223 | Validation Accuracy: 10.6% | Time elapsed: 127.39s
# Epoch 3 | Training Loss (Avg): 2.346641 | Validation Accuracy: 9.44% | Time elapsed: 127.35s
# Epoch 4 | Training Loss (Avg): 2.340915 | Validation Accuracy: 8.9% | Time elapsed: 127.30s
# Epoch 5 | Training Loss (Avg): 2.336844 | Validation Accuracy: 9.96% | Time elapsed: 127.27s
# Epoch 6 | Training Loss (Avg): 2.333319 | Validation Accuracy: 10.6% | Time elapsed: 127.30s
# Epoch 7 | Training Loss (Avg): 2.331444 | Validation Accuracy: 8.9% | Time elapsed: 127.33s
# Epoch 8 | Training Loss (Avg): 2.329280 | Validation Accuracy: 9.44% | Time elapsed: 127.32s
# Epoch 9 | Training Loss (Avg): 2.327941 | Validation Accuracy: 10.6% | Time elapsed: 127.30s
# Epoch 10 | Training Loss (Avg): 2.326415 | Validation Accuracy: 10.04% | Time elapsed: 127.32s
# ...

# %%
vgg_adam_cifar10.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # Adam, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adam_cifar10'

wideresnet_adam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adam_cifar10_train_loss, wideresnet_adam_cifar10_val_error = wideresnet_adam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.471089 | Validation Accuracy: 9.68% | Time elapsed: 183.05s
# Epoch 2 | Training Loss (Avg): 2.328187 | Validation Accuracy: 10.28% | Time elapsed: 180.53s
# Epoch 3 | Training Loss (Avg): 2.414219 | Validation Accuracy: 12.38% | Time elapsed: 178.56s
# Epoch 4 | Training Loss (Avg): 2.873220 | Validation Accuracy: 10.28% | Time elapsed: 180.78s
# Epoch 5 | Training Loss (Avg): 2.722132 | Validation Accuracy: 9.68% | Time elapsed: 182.46s
# Epoch 6 | Training Loss (Avg): 2.641136 | Validation Accuracy: 10.38% | Time elapsed: 183.35s
# Epoch 7 | Training Loss (Avg): 2.821626 | Validation Accuracy: 10.7% | Time elapsed: 183.64s
# Epoch 8 | Training Loss (Avg): 2.686955 | Validation Accuracy: 9.34% | Time elapsed: 183.54s
# Epoch 9 | Training Loss (Avg): 2.775008 | Validation Accuracy: 10.06% | Time elapsed: 183.35s
# Epoch 10 | Training Loss (Avg): 2.702574 | Validation Accuracy: 9.6% | Time elapsed: 183.64s
# ...

# %%
wideresnet_adam_cifar10.test()
# Out:
# Accuracy of the model on test images: 41.0%

# %% [markdown]
# # Adamw, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adamw'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adamw_cifar10'

resnet_adamw_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adamw_cifar10_train_loss, resnet_adamw_cifar10_val_error = resnet_adamw_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.911309 | Validation Accuracy: 35.92% | Time elapsed: 34.04s
# Epoch 2 | Training Loss (Avg): 1.548076 | Validation Accuracy: 41.44% | Time elapsed: 34.54s
# Epoch 3 | Training Loss (Avg): 1.403812 | Validation Accuracy: 50.24% | Time elapsed: 34.49s
# Epoch 4 | Training Loss (Avg): 1.304353 | Validation Accuracy: 59.66% | Time elapsed: 34.08s
# Epoch 5 | Training Loss (Avg): 1.221570 | Validation Accuracy: 56.5% | Time elapsed: 34.29s
# Epoch 6 | Training Loss (Avg): 1.148959 | Validation Accuracy: 62.48% | Time elapsed: 34.28s
# Epoch 7 | Training Loss (Avg): 1.072007 | Validation Accuracy: 59.28% | Time elapsed: 34.67s
# Epoch 8 | Training Loss (Avg): 1.026624 | Validation Accuracy: 58.62% | Time elapsed: 34.62s
# Epoch 9 | Training Loss (Avg): 0.986564 | Validation Accuracy: 66.02% | Time elapsed: 34.10s
# Epoch 10 | Training Loss (Avg): 0.917530 | Validation Accuracy: 65.3% | Time elapsed: 34.73s
# ...

# %%
resnet_adamw_cifar10.test()
# Out:
# Accuracy of the model on test images: 74.0%

# %% [markdown]
# # Adamw, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adamw'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adamw_cifar10'

vgg_adamw_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adamw_cifar10_train_loss, vgg_adamw_cifar10_val_error = vgg_adamw_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.405894 | Validation Accuracy: 10.46% | Time elapsed: 124.29s
# Epoch 2 | Training Loss (Avg): 2.307184 | Validation Accuracy: 9.84% | Time elapsed: 124.27s
# Epoch 3 | Training Loss (Avg): 2.305920 | Validation Accuracy: 10.46% | Time elapsed: 124.26s
# Epoch 4 | Training Loss (Avg): 2.305094 | Validation Accuracy: 9.56% | Time elapsed: 124.28s
# Epoch 5 | Training Loss (Avg): 2.304552 | Validation Accuracy: 9.84% | Time elapsed: 124.25s
# Epoch 6 | Training Loss (Avg): 2.304674 | Validation Accuracy: 10.16% | Time elapsed: 124.24s
# Epoch 7 | Training Loss (Avg): 2.304009 | Validation Accuracy: 10.4% | Time elapsed: 124.25s
# Epoch 8 | Training Loss (Avg): 2.304029 | Validation Accuracy: 10.16% | Time elapsed: 124.24s
# Epoch 9 | Training Loss (Avg): 2.303690 | Validation Accuracy: 9.84% | Time elapsed: 124.26s
# Epoch 10 | Training Loss (Avg): 2.303832 | Validation Accuracy: 9.84% | Time elapsed: 124.24s
# ...

# %%
vgg_adamw_cifar10.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # Adamw, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adamw'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adamw_cifar10'

wideresnet_adamw_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adamw_cifar10_train_loss, wideresnet_adamw_cifar10_val_error = wideresnet_adamw_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.603158 | Validation Accuracy: 14.26% | Time elapsed: 182.55s
# Epoch 2 | Training Loss (Avg): 2.397707 | Validation Accuracy: 10.0% | Time elapsed: 174.58s
# Epoch 3 | Training Loss (Avg): 2.348554 | Validation Accuracy: 10.1% | Time elapsed: 174.40s
# Epoch 4 | Training Loss (Avg): 2.315541 | Validation Accuracy: 9.94% | Time elapsed: 173.18s
# Epoch 5 | Training Loss (Avg): 2.315988 | Validation Accuracy: 9.72% | Time elapsed: 173.90s
# Epoch 6 | Training Loss (Avg): 2.315967 | Validation Accuracy: 9.82% | Time elapsed: 173.66s
# Epoch 7 | Training Loss (Avg): 2.315738 | Validation Accuracy: 10.02% | Time elapsed: 173.60s
# Epoch 8 | Training Loss (Avg): 2.314214 | Validation Accuracy: 9.72% | Time elapsed: 173.34s
# Epoch 9 | Training Loss (Avg): 2.316146 | Validation Accuracy: 10.18% | Time elapsed: 173.10s
# Epoch 10 | Training Loss (Avg): 2.315917 | Validation Accuracy: 9.44% | Time elapsed: 173.55s
# ...

# %%
wideresnet_adamw_cifar10.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # NAdam, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'nadam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.01
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_nadam_cifar10'

resnet_nadam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_nadam_cifar10_train_loss, resnet_nadam_cifar10_val_error = resnet_nadam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.434847 | Validation Accuracy: 47.14% | Time elapsed: 72.29s
# Epoch 2 | Training Loss (Avg): 1.295617 | Validation Accuracy: 48.18% | Time elapsed: 71.92s
# Epoch 3 | Training Loss (Avg): 1.237078 | Validation Accuracy: 43.44% | Time elapsed: 72.44s
# Epoch 4 | Training Loss (Avg): 1.200927 | Validation Accuracy: 44.3% | Time elapsed: 72.55s
# Epoch 5 | Training Loss (Avg): 1.176403 | Validation Accuracy: 49.5% | Time elapsed: 72.86s
# Epoch 6 | Training Loss (Avg): 1.161495 | Validation Accuracy: 56.94% | Time elapsed: 72.22s
# Epoch 7 | Training Loss (Avg): 1.154744 | Validation Accuracy: 54.3% | Time elapsed: 72.05s
# Epoch 8 | Training Loss (Avg): 1.146159 | Validation Accuracy: 52.26% | Time elapsed: 72.01s
# Epoch 9 | Training Loss (Avg): 1.144450 | Validation Accuracy: 61.82% | Time elapsed: 72.75s
# Epoch 10 | Training Loss (Avg): 1.137893 | Validation Accuracy: 43.86% | Time elapsed: 72.12s
# ...

# %%
resnet_nadam_cifar10.test()
# Out:
# Accuracy of the model on test images: 70.0%

# %% [markdown]
# # NAdam, VGG

# %%
model_type = 'vgg'
optimizer_type = 'nadam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_nadam_cifar10'

vgg_nadam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_nadam_cifar10_train_loss, vgg_nadam_cifar10_val_error = vgg_nadam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2.577307 | Validation Accuracy: 10.04% | Time elapsed: 269.70s
# Epoch 2 | Training Loss (Avg): 2.351275 | Validation Accuracy: 9.38% | Time elapsed: 266.77s
# Epoch 3 | Training Loss (Avg): 2.348705 | Validation Accuracy: 10.04% | Time elapsed: 268.07s
# Epoch 4 | Training Loss (Avg): 2.345305 | Validation Accuracy: 9.78% | Time elapsed: 265.94s
# Epoch 5 | Training Loss (Avg): 2.339520 | Validation Accuracy: 10.62% | Time elapsed: 267.85s
# Epoch 6 | Training Loss (Avg): 2.334883 | Validation Accuracy: 9.34% | Time elapsed: 265.91s
# Epoch 7 | Training Loss (Avg): 2.334376 | Validation Accuracy: 9.78% | Time elapsed: 268.06s
# Epoch 8 | Training Loss (Avg): 2.331428 | Validation Accuracy: 10.28% | Time elapsed: 265.26s
# Epoch 9 | Training Loss (Avg): 2.328322 | Validation Accuracy: 9.38% | Time elapsed: 267.21s
# Epoch 10 | Training Loss (Avg): 2.327963 | Validation Accuracy: 9.38% | Time elapsed: 264.93s
# ...

# %%
vgg_nadam_cifar10.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # NAdam, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'nadam'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_nadam_cifar10'

wideresnet_nadam_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_nadam_cifar10_train_loss, wideresnet_nadam_cifar10_val_error = wideresnet_nadam_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.490587 | Validation Accuracy: 9.58% | Time elapsed: 289.44s
# Epoch 2 | Training Loss (Avg): 5.624947 | Validation Accuracy: 10.06% | Time elapsed: 289.59s
# Epoch 3 | Training Loss (Avg): 3.148039 | Validation Accuracy: 10.84% | Time elapsed: 289.69s
# Epoch 4 | Training Loss (Avg): 3.052598 | Validation Accuracy: 9.92% | Time elapsed: 289.66s
# Epoch 5 | Training Loss (Avg): 2.958429 | Validation Accuracy: 10.3% | Time elapsed: 289.58s
# Epoch 6 | Training Loss (Avg): 2.959439 | Validation Accuracy: 8.92% | Time elapsed: 289.80s
# Epoch 7 | Training Loss (Avg): 2.982475 | Validation Accuracy: 9.92% | Time elapsed: 289.55s
# Epoch 8 | Training Loss (Avg): 2.935080 | Validation Accuracy: 10.76% | Time elapsed: 289.14s
# Epoch 9 | Training Loss (Avg): 2.878691 | Validation Accuracy: 10.36% | Time elapsed: 289.28s
# Epoch 10 | Training Loss (Avg): 2.849926 | Validation Accuracy: 10.84% | Time elapsed: 289.60s
# ...

# %%
wideresnet_nadam_cifar10.test()
# Out:
# Accuracy of the model on test images: 32.0%

# %% [markdown]
# # Adadelta, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adadelta'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adadelta_cifar10'

resnet_adadelta_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adadelta_cifar10_train_loss, resnet_adadelta_cifar10_val_error = resnet_adadelta_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.515291 | Validation Accuracy: 54.16% | Time elapsed: 74.52s
# Epoch 2 | Training Loss (Avg): 1.049780 | Validation Accuracy: 61.12% | Time elapsed: 74.13s
# Epoch 3 | Training Loss (Avg): 0.857420 | Validation Accuracy: 64.66% | Time elapsed: 75.17s
# Epoch 4 | Training Loss (Avg): 0.720035 | Validation Accuracy: 68.7% | Time elapsed: 74.06s
# Epoch 5 | Training Loss (Avg): 0.601808 | Validation Accuracy: 71.24% | Time elapsed: 74.42s
# Epoch 6 | Training Loss (Avg): 0.502501 | Validation Accuracy: 71.32% | Time elapsed: 74.76s
# Epoch 7 | Training Loss (Avg): 0.417275 | Validation Accuracy: 71.38% | Time elapsed: 74.42s
# Epoch 8 | Training Loss (Avg): 0.347953 | Validation Accuracy: 69.96% | Time elapsed: 74.05s
# Epoch 9 | Training Loss (Avg): 0.292369 | Validation Accuracy: 70.94% | Time elapsed: 74.42s
# Epoch 10 | Training Loss (Avg): 0.250637 | Validation Accuracy: 72.42% | Time elapsed: 74.53s
# ...

# %%
resnet_adadelta_cifar10.test()
# Out:
# Accuracy of the model on test images: 76.0%

# %% [markdown]
# # Adadelta, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adadelta'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.001
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adadelta_cifar10'

vgg_adadelta_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adadelta_cifar10_train_loss, vgg_adadelta_cifar10_val_error = vgg_adadelta_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.607335 | Validation Accuracy: 13.46% | Time elapsed: 280.80s
# Epoch 2 | Training Loss (Avg): 2.532601 | Validation Accuracy: 18.4% | Time elapsed: 282.64s
# Epoch 3 | Training Loss (Avg): 2.353980 | Validation Accuracy: 24.72% | Time elapsed: 280.80s
# Epoch 4 | Training Loss (Avg): 2.178676 | Validation Accuracy: 27.26% | Time elapsed: 282.80s
# Epoch 5 | Training Loss (Avg): 2.074696 | Validation Accuracy: 30.34% | Time elapsed: 280.90s
# Epoch 6 | Training Loss (Avg): 1.985359 | Validation Accuracy: 31.32% | Time elapsed: 282.99s
# Epoch 7 | Training Loss (Avg): 1.912710 | Validation Accuracy: 34.78% | Time elapsed: 280.87s
# Epoch 8 | Training Loss (Avg): 1.844746 | Validation Accuracy: 33.6% | Time elapsed: 282.97s
# Epoch 9 | Training Loss (Avg): 1.787558 | Validation Accuracy: 36.56% | Time elapsed: 280.71s
# Epoch 10 | Training Loss (Avg): 1.738934 | Validation Accuracy: 37.78% | Time elapsed: 282.76s
# ...

# %%
vgg_adadelta_cifar10.test()
# Out:
# Accuracy of the model on test images: 60.0%

# %% [markdown]
# # Adadelta, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adadelta'
dataset = 'cifar10'
train_val_split = 0.9
batch_size = 32
epochs = 50
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adadelta_cifar10'

wideresnet_adadelta_cifar10 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adadelta_cifar10_train_loss, wideresnet_adadelta_cifar10_val_error = wideresnet_adadelta_cifar10.train()
# Out:
# Epoch 1 | Training Loss (Avg): 1.789960 | Validation Accuracy: 47.84% | Time elapsed: 299.10s
# Epoch 2 | Training Loss (Avg): 1.231073 | Validation Accuracy: 60.58% | Time elapsed: 298.89s
# Epoch 3 | Training Loss (Avg): 0.975483 | Validation Accuracy: 64.34% | Time elapsed: 299.24s
# Epoch 4 | Training Loss (Avg): 0.791322 | Validation Accuracy: 68.94% | Time elapsed: 299.37s
# Epoch 5 | Training Loss (Avg): 0.642767 | Validation Accuracy: 68.76% | Time elapsed: 299.55s
# Epoch 6 | Training Loss (Avg): 0.527205 | Validation Accuracy: 72.4% | Time elapsed: 299.50s
# Epoch 7 | Training Loss (Avg): 0.438463 | Validation Accuracy: 71.68% | Time elapsed: 299.45s
# Epoch 8 | Training Loss (Avg): 0.358514 | Validation Accuracy: 72.14% | Time elapsed: 299.23s
# Epoch 9 | Training Loss (Avg): 0.297948 | Validation Accuracy: 72.52% | Time elapsed: 299.41s
# Epoch 10 | Training Loss (Avg): 0.255734 | Validation Accuracy: 74.72% | Time elapsed: 299.55s
# ...

# %%
wideresnet_adadelta_cifar10.test()
# Out:
# Accuracy of the model on test images: 73.0%

# %% [markdown]
# # Visualizations - Train Loss vs Epoch (for all the above Optimization algorithms and 3 model types)

# %%
plt.figure(figsize = (10, 7))
plt.title("ResNet")
plt.plot(resnet_padam_cifar10_p8_train_loss, label = 'padam')
plt.plot(resnet_sgd_cifar10_train_loss, label = 'sgd')
plt.plot(resnet_adam_cifar10_train_loss, label = 'adam')
plt.plot(resnet_adamw_cifar10_train_loss, label = 'adamw')
plt.plot(resnet_nadam_cifar10_train_loss, label = 'nadam')
plt.plot(resnet_adadelta_cifar10_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("VGG")
plt.plot(vgg_padam_cifar10_p8_train_loss, label = 'padam')
plt.plot(vgg_sgd_cifar10_train_loss, label = 'sgd')
plt.plot(vgg_adam_cifar10_train_loss, label = 'adam')
plt.plot(vgg_adamw_cifar10_train_loss, label = 'adamw')
plt.plot(vgg_nadam_cifar10_train_loss, label = 'nadam')
plt.plot(vgg_adadelta_cifar10_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("Wide-ResNet")
plt.plot(wideresnet_padam_cifar10_p8_train_loss, label = 'padam')
plt.plot(wideresnet_sgd_cifar10_train_loss, label = 'sgd')
plt.plot(wideresnet_adam_cifar10_train_loss, label = 'adam')
plt.plot(wideresnet_adamw_cifar10_train_loss, label = 'adamw')
plt.plot(wideresnet_nadam_cifar10_train_loss, label = 'nadam')
plt.plot(wideresnet_adadelta_cifar10_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Visualizations - Train Loss vs Validation Error (for all the above Optimization algorithms and 3 model types)

# %%
plt.figure(figsize = (10, 7))
plt.title("ResNet")
plt.plot(resnet_padam_cifar10_p8_val_error, label = 'padam')
plt.plot(resnet_sgd_cifar10_val_error, label = 'sgd')
plt.plot(resnet_adam_cifar10_val_error, label = 'adam')
plt.plot(resnet_adamw_cifar10_val_error, label = 'adamw')
plt.plot(resnet_nadam_cifar10_val_error, label = 'nadam')
plt.plot(resnet_adadelta_cifar10_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("VGG")
plt.plot(vgg_padam_cifar10_p8_val_error, label = 'padam')
plt.plot(vgg_sgd_cifar10_val_error, label = 'sgd')
plt.plot(vgg_adam_cifar10_val_error, label = 'adam')
plt.plot(vgg_adamw_cifar10_val_error, label = 'adamw')
plt.plot(vgg_nadam_cifar10_val_error, label = 'nadam')
plt.plot(vgg_adadelta_cifar10_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("Wide-ResNet")
plt.plot(wideresnet_padam_cifar10_p8_val_error, label = 'padam')
plt.plot(wideresnet_sgd_cifar10_val_error, label = 'sgd')
plt.plot(wideresnet_adam_cifar10_val_error, label = 'adam')
plt.plot(wideresnet_adamw_cifar10_val_error, label = 'adamw')
plt.plot(wideresnet_nadam_cifar10_val_error, label = 'nadam')
plt.plot(wideresnet_adadelta_cifar10_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

# %% [markdown]
# # Validation Accuracy table for all the above algorithms and 3 model types
