# %%
from model import *

# %% [markdown]
# # Padam, Resnet, p = 1/4

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/4
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar100_p4'

resnet_padam_cifar100_p4 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar100_p4_train_loss, resnet_padam_cifar100_p4_val_error = resnet_padam_cifar100_p4.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.185115 | Validation Accuracy: 12.72% | Time elapsed: 38.82s
# Epoch 2 | Training Loss (Avg): 3.621368 | Validation Accuracy: 15.8% | Time elapsed: 37.43s
# Epoch 3 | Training Loss (Avg): 3.400654 | Validation Accuracy: 18.32% | Time elapsed: 36.22s
# Epoch 4 | Training Loss (Avg): 3.261560 | Validation Accuracy: 20.5% | Time elapsed: 36.86s
# Epoch 5 | Training Loss (Avg): 3.189997 | Validation Accuracy: 21.98% | Time elapsed: 36.11s
# Epoch 6 | Training Loss (Avg): 3.140949 | Validation Accuracy: 21.82% | Time elapsed: 37.06s
# Epoch 7 | Training Loss (Avg): 3.094390 | Validation Accuracy: 24.36% | Time elapsed: 36.33s
# Epoch 8 | Training Loss (Avg): 3.071003 | Validation Accuracy: 24.02% | Time elapsed: 36.87s
# Epoch 9 | Training Loss (Avg): 3.044294 | Validation Accuracy: 23.2% | Time elapsed: 35.34s
# Epoch 10 | Training Loss (Avg): 3.034148 | Validation Accuracy: 23.78% | Time elapsed: 37.30s
# ...

# %%
resnet_padam_cifar100_p4.test()
# Out:
# Accuracy of the model on test images: 42.0%

# %% [markdown]
# # Padam, Resnet, p = 1/8

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar100_p8'

resnet_padam_cifar100_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar100_p8_train_loss, resnet_padam_cifar100_p8_val_error = resnet_padam_cifar100_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.902563 | Validation Accuracy: 19.26% | Time elapsed: 35.89s
# Epoch 2 | Training Loss (Avg): 3.122886 | Validation Accuracy: 27.9% | Time elapsed: 37.07s
# Epoch 3 | Training Loss (Avg): 2.741797 | Validation Accuracy: 30.64% | Time elapsed: 35.89s
# Epoch 4 | Training Loss (Avg): 2.514645 | Validation Accuracy: 35.0% | Time elapsed: 36.92s
# Epoch 5 | Training Loss (Avg): 2.360044 | Validation Accuracy: 35.74% | Time elapsed: 35.64s
# Epoch 6 | Training Loss (Avg): 2.241932 | Validation Accuracy: 38.82% | Time elapsed: 37.60s
# Epoch 7 | Training Loss (Avg): 2.135447 | Validation Accuracy: 38.7% | Time elapsed: 36.78s
# Epoch 8 | Training Loss (Avg): 2.063663 | Validation Accuracy: 38.94% | Time elapsed: 37.21s
# Epoch 9 | Training Loss (Avg): 1.994628 | Validation Accuracy: 39.36% | Time elapsed: 37.06s
# Epoch 10 | Training Loss (Avg): 1.933045 | Validation Accuracy: 40.38% | Time elapsed: 37.81s
# ...

# %%
resnet_padam_cifar100_p8.test()
# Out:
# Accuracy of the model on test images: 49.0%

# %% [markdown]
# # Padam, Resnet, p = 1/16

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/16
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar100_p16'

resnet_padam_cifar100_p16 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar100_p16_train_loss, resnet_padam_cifar100_p16_val_error = resnet_padam_cifar100_p16.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.874687 | Validation Accuracy: 19.78% | Time elapsed: 35.16s
# Epoch 2 | Training Loss (Avg): 3.064949 | Validation Accuracy: 29.08% | Time elapsed: 34.35s
# Epoch 3 | Training Loss (Avg): 2.652788 | Validation Accuracy: 33.46% | Time elapsed: 33.62s
# Epoch 4 | Training Loss (Avg): 2.370390 | Validation Accuracy: 36.8% | Time elapsed: 33.78s
# Epoch 5 | Training Loss (Avg): 2.154386 | Validation Accuracy: 38.16% | Time elapsed: 33.51s
# Epoch 6 | Training Loss (Avg): 1.997773 | Validation Accuracy: 40.56% | Time elapsed: 33.99s
# Epoch 7 | Training Loss (Avg): 1.840056 | Validation Accuracy: 39.08% | Time elapsed: 34.60s
# Epoch 8 | Training Loss (Avg): 1.717327 | Validation Accuracy: 41.68% | Time elapsed: 34.55s
# Epoch 9 | Training Loss (Avg): 1.600815 | Validation Accuracy: 41.42% | Time elapsed: 33.97s
# Epoch 10 | Training Loss (Avg): 1.509934 | Validation Accuracy: 40.74% | Time elapsed: 33.17s
# ...

# %%
resnet_padam_cifar100_p16.test()
# Out:
# Accuracy of the model on test images: 48.0%

# %% [markdown]
# # Padam, Resnet, p = 1/2

# %%
model_type = 'resnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/2
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_padam_cifar100_p2'

resnet_padam_cifar100_p2 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_padam_cifar100_p2_train_loss, resnet_padam_cifar100_p2_val_error = resnet_padam_cifar100_p2.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.922218 | Validation Accuracy: 0.82% | Time elapsed: 35.55s
# Epoch 2 | Training Loss (Avg): 4.654874 | Validation Accuracy: 1.34% | Time elapsed: 35.98s
# Epoch 3 | Training Loss (Avg): 4.617785 | Validation Accuracy: 2.4% | Time elapsed: 35.86s
# Epoch 4 | Training Loss (Avg): 4.590608 | Validation Accuracy: 1.68% | Time elapsed: 37.40s
# Epoch 5 | Training Loss (Avg): 4.590132 | Validation Accuracy: 1.62% | Time elapsed: 35.49s
# Epoch 6 | Training Loss (Avg): 4.600400 | Validation Accuracy: 1.02% | Time elapsed: 36.44s
# Epoch 7 | Training Loss (Avg): 4.583897 | Validation Accuracy: 1.8% | Time elapsed: 36.39s
# Epoch 8 | Training Loss (Avg): 4.584556 | Validation Accuracy: 1.6% | Time elapsed: 37.07s
# Epoch 9 | Training Loss (Avg): 4.581917 | Validation Accuracy: 1.82% | Time elapsed: 35.21s
# Epoch 10 | Training Loss (Avg): 4.580979 | Validation Accuracy: 2.38% | Time elapsed: 37.39s
# ...

# %%
resnet_padam_cifar100_p2.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # Visualizations - Train Loss vs Epoch (Padam, Resnet, for multiple p)

# %%
plt.plot(resnet_padam_cifar100_p2_train_loss, label = 'p=1/2')
plt.plot(resnet_padam_cifar100_p4_train_loss, label = 'p=1/4')
plt.plot(resnet_padam_cifar100_p8_train_loss, label = 'p=1/8')
plt.plot(resnet_padam_cifar100_p16_train_loss, label = 'p=1/16')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Visualizations - Validation Error vs Epoch (Padam, Resnet, for multiple p)

# %%
plt.plot(resnet_padam_cifar100_p2_val_error, label = 'p=1/2')
plt.plot(resnet_padam_cifar100_p4_val_error, label = 'p=1/4')
plt.plot(resnet_padam_cifar100_p8_val_error, label = 'p=1/8')
plt.plot(resnet_padam_cifar100_p16_val_error, label = 'p=1/16')
plt.xlabel("Epochs")
plt.ylabel("Validation Error per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Padam, VGG, p = 1/8

# %%
model_type = 'vgg'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_padam_cifar100_p8'

vgg_padam_cifar10_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_padam_cifar100_p8_train_loss, vgg_padam_cifar100_p8_val_error = vgg_padam_cifar10_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.935520 | Validation Accuracy: 0.82% | Time elapsed: 85.23s
# Epoch 2 | Training Loss (Avg): 4.757226 | Validation Accuracy: 0.94% | Time elapsed: 84.97s
# Epoch 3 | Training Loss (Avg): 4.750075 | Validation Accuracy: 1.04% | Time elapsed: 84.96s
# Epoch 4 | Training Loss (Avg): 4.746294 | Validation Accuracy: 0.98% | Time elapsed: 84.96s
# Epoch 5 | Training Loss (Avg): 4.743410 | Validation Accuracy: 1.28% | Time elapsed: 84.83s
# Epoch 6 | Training Loss (Avg): 4.741522 | Validation Accuracy: 1.04% | Time elapsed: 85.06s
# Epoch 7 | Training Loss (Avg): 4.742070 | Validation Accuracy: 0.9% | Time elapsed: 84.82s
# Epoch 8 | Training Loss (Avg): 4.742059 | Validation Accuracy: 0.96% | Time elapsed: 84.91s
# Epoch 9 | Training Loss (Avg): 4.739145 | Validation Accuracy: 1.0% | Time elapsed: 84.86s
# Epoch 10 | Training Loss (Avg): 4.740567 | Validation Accuracy: 0.86% | Time elapsed: 84.74s
# ...

# %%
vgg_padam_cifar10_p8.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # Padam, WideResnet, p = 1/8

# %%
model_type = 'wideresnet'          #Options: 'resnet', 'vgg', 'wideresnet'
optimizer_type = 'padam'       #Options: 'padam', 'sgd', 'adam', 'adamw', 'nadam', 'adadelta'
dataset = 'cifar100'            #Options: 'cifar10', 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_padam_cifar100_p8'

wideresnet_padam_cifar100_p8 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_padam_cifar100_p8_train_loss, wideresnet_padam_cifar100_p8_val_error = wideresnet_padam_cifar100_p8.train()
# Out:
# Epoch 1 | Training Loss (Avg): 5.152162 | Validation Accuracy: 3.46% | Time elapsed: 92.86s
# Epoch 2 | Training Loss (Avg): 4.193109 | Validation Accuracy: 8.16% | Time elapsed: 91.55s
# Epoch 3 | Training Loss (Avg): 3.892702 | Validation Accuracy: 11.48% | Time elapsed: 92.02s
# Epoch 4 | Training Loss (Avg): 3.741866 | Validation Accuracy: 14.88% | Time elapsed: 90.90s
# Epoch 5 | Training Loss (Avg): 3.641068 | Validation Accuracy: 14.68% | Time elapsed: 92.29s
# Epoch 6 | Training Loss (Avg): 3.549972 | Validation Accuracy: 16.84% | Time elapsed: 90.63s
# Epoch 7 | Training Loss (Avg): 3.476847 | Validation Accuracy: 18.68% | Time elapsed: 91.86s
# Epoch 8 | Training Loss (Avg): 3.401147 | Validation Accuracy: 19.2% | Time elapsed: 90.65s
# Epoch 9 | Training Loss (Avg): 3.344758 | Validation Accuracy: 18.6% | Time elapsed: 92.24s
# Epoch 10 | Training Loss (Avg): 3.298257 | Validation Accuracy: 18.0% | Time elapsed: 90.44s
# ...

# %%
wideresnet_padam_cifar100_p8.test()
# Out:
# Accuracy of the model on test images: 42.0%

# %% [markdown]
# # SGD, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'sgd'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_sgd_cifar100'

resnet_sgd_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_sgd_cifar100_train_loss, resnet_sgd_cifar100_val_error = resnet_sgd_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.218905 | Validation Accuracy: 11.9% | Time elapsed: 23.86s
# Epoch 2 | Training Loss (Avg): 3.517421 | Validation Accuracy: 20.58% | Time elapsed: 23.91s
# Epoch 3 | Training Loss (Avg): 3.213474 | Validation Accuracy: 23.86% | Time elapsed: 23.66s
# Epoch 4 | Training Loss (Avg): 2.980142 | Validation Accuracy: 26.3% | Time elapsed: 24.02s
# Epoch 5 | Training Loss (Avg): 2.845327 | Validation Accuracy: 29.68% | Time elapsed: 23.79s
# Epoch 6 | Training Loss (Avg): 2.723853 | Validation Accuracy: 27.72% | Time elapsed: 24.07s
# Epoch 7 | Training Loss (Avg): 2.546799 | Validation Accuracy: 29.98% | Time elapsed: 23.71s
# Epoch 8 | Training Loss (Avg): 2.440514 | Validation Accuracy: 32.88% | Time elapsed: 24.03s
# Epoch 9 | Training Loss (Avg): 2.286177 | Validation Accuracy: 32.24% | Time elapsed: 23.77s
# Epoch 10 | Training Loss (Avg): 2.170317 | Validation Accuracy: 35.12% | Time elapsed: 24.00s
# ...

# %%
resnet_sgd_cifar100.test()
# Out:
# Accuracy of the model on test images: 42.0%

# %% [markdown]
# # SGD, VGG

# %%
model_type = 'vgg'
optimizer_type = 'sgd'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_sgd_cifar100'

vgg_sgd_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_sgd_cifar100_train_loss, vgg_sgd_cifar100_val_error = vgg_sgd_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 51.43s
# Epoch 2 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 50.18s
# Epoch 3 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.92s
# Epoch 4 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.99s
# Epoch 5 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.91s
# Epoch 6 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 50.03s
# Epoch 7 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.86s
# Epoch 8 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.96s
# Epoch 9 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 50.07s
# Epoch 10 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.95s
# Epoch 11 | Training Loss (Avg): nan | Validation Accuracy: 1.12% | Time elapsed: 49.96s
# ...

# %%
vgg_sgd_cifar100.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # SGD, WideResnet

# %%
model_type = 'wideresnet'
optimizer_type = 'sgd'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_sgd_cifar100'

wideresnet_sgd_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_sgd_cifar100_train_loss, wideresnet_sgd_cifar100_val_error = wideresnet_sgd_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 5.657383 | Validation Accuracy: 1.74% | Time elapsed: 67.73s
# Epoch 2 | Training Loss (Avg): 4.389558 | Validation Accuracy: 4.72% | Time elapsed: 65.36s
# Epoch 3 | Training Loss (Avg): 4.169902 | Validation Accuracy: 6.4% | Time elapsed: 63.72s
# Epoch 4 | Training Loss (Avg): 3.995941 | Validation Accuracy: 9.12% | Time elapsed: 65.32s
# Epoch 5 | Training Loss (Avg): 3.870657 | Validation Accuracy: 11.86% | Time elapsed: 63.76s
# Epoch 6 | Training Loss (Avg): 3.741386 | Validation Accuracy: 13.84% | Time elapsed: 63.07s
# Epoch 7 | Training Loss (Avg): 3.633974 | Validation Accuracy: 14.78% | Time elapsed: 62.89s
# Epoch 8 | Training Loss (Avg): 3.519637 | Validation Accuracy: 15.72% | Time elapsed: 63.50s
# Epoch 9 | Training Loss (Avg): 3.422786 | Validation Accuracy: 18.1% | Time elapsed: 62.99s
# Epoch 10 | Training Loss (Avg): 3.306714 | Validation Accuracy: 20.58% | Time elapsed: 62.89s
# ...

# %%
wideresnet_sgd_cifar100.test()
# Out:
# Accuracy of the model on test images: 35.0%

# %% [markdown]
# # Adam, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adam_cifar100'

resnet_adam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adam_cifar100_train_loss, resnet_adam_cifar100_val_error = resnet_adam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.859321 | Validation Accuracy: 0.76% | Time elapsed: 34.73s
# Epoch 2 | Training Loss (Avg): 4.605195 | Validation Accuracy: 1.2% | Time elapsed: 36.28s
# Epoch 3 | Training Loss (Avg): 4.606618 | Validation Accuracy: 2.18% | Time elapsed: 37.17s
# Epoch 4 | Training Loss (Avg): 4.627316 | Validation Accuracy: 0.96% | Time elapsed: 35.11s
# Epoch 5 | Training Loss (Avg): 4.645991 | Validation Accuracy: 1.1% | Time elapsed: 32.19s
# Epoch 6 | Training Loss (Avg): 4.723057 | Validation Accuracy: 0.76% | Time elapsed: 32.58s
# Epoch 7 | Training Loss (Avg): 4.684384 | Validation Accuracy: 1.1% | Time elapsed: 32.16s
# Epoch 8 | Training Loss (Avg): 4.673949 | Validation Accuracy: 1.26% | Time elapsed: 32.91s
# Epoch 9 | Training Loss (Avg): 4.680994 | Validation Accuracy: 1.9% | Time elapsed: 32.86s
# Epoch 10 | Training Loss (Avg): 4.648107 | Validation Accuracy: 0.94% | Time elapsed: 33.06s
# ...

# %%
resnet_adam_cifar100.test()
# Out:
# Accuracy of the model on test images: 31.0%

# %% [markdown]
# # Adam, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adam_cifar100'

vgg_adam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adam_cifar100_train_loss, vgg_adam_cifar100_val_error = vgg_adam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 37126811466172744073216.000000 | Validation Accuracy: 0.7% | Time elapsed: 79.49s
# Epoch 2 | Training Loss (Avg): 4.900739 | Validation Accuracy: 1.0% | Time elapsed: 78.76s
# Epoch 3 | Training Loss (Avg): 4.965122 | Validation Accuracy: 1.06% | Time elapsed: 78.87s
# Epoch 4 | Training Loss (Avg): 4.964196 | Validation Accuracy: 0.94% | Time elapsed: 78.87s
# Epoch 5 | Training Loss (Avg): 4.936969 | Validation Accuracy: 0.98% | Time elapsed: 78.49s
# Epoch 6 | Training Loss (Avg): 4.943426 | Validation Accuracy: 0.86% | Time elapsed: 78.56s
# Epoch 7 | Training Loss (Avg): 4.958113 | Validation Accuracy: 1.14% | Time elapsed: 78.36s
# Epoch 8 | Training Loss (Avg): 4.946381 | Validation Accuracy: 0.8% | Time elapsed: 78.57s
# Epoch 9 | Training Loss (Avg): 4.945360 | Validation Accuracy: 0.68% | Time elapsed: 78.52s
# Epoch 10 | Training Loss (Avg): 4.955926 | Validation Accuracy: 0.9% | Time elapsed: 78.47s
# ...

# %%
vgg_adam_cifar100.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # Adam, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adam_cifar100'

wideresnet_adam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adam_cifar100_train_loss, wideresnet_adam_cifar100_val_error = wideresnet_adam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 5.769763 | Validation Accuracy: 0.94% | Time elapsed: 86.84s
# Epoch 2 | Training Loss (Avg): 4.840409 | Validation Accuracy: 1.08% | Time elapsed: 86.71s
# Epoch 3 | Training Loss (Avg): 4.854251 | Validation Accuracy: 0.44% | Time elapsed: 86.86s
# Epoch 4 | Training Loss (Avg): 5.028931 | Validation Accuracy: 1.04% | Time elapsed: 86.65s
# Epoch 5 | Training Loss (Avg): 5.020161 | Validation Accuracy: 0.84% | Time elapsed: 86.81s
# Epoch 6 | Training Loss (Avg): 4.995555 | Validation Accuracy: 1.16% | Time elapsed: 86.29s
# Epoch 7 | Training Loss (Avg): 4.997024 | Validation Accuracy: 0.92% | Time elapsed: 86.30s
# Epoch 8 | Training Loss (Avg): 5.002392 | Validation Accuracy: 1.1% | Time elapsed: 87.02s
# Epoch 9 | Training Loss (Avg): 5.023884 | Validation Accuracy: 0.74% | Time elapsed: 86.78s
# Epoch 10 | Training Loss (Avg): 5.020573 | Validation Accuracy: 1.04% | Time elapsed: 86.53s
# ...

# %%
wideresnet_adam_cifar100.test()
# Out:
# Accuracy of the model on test images: 28.0%

# %% [markdown]
# # Adamw, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adamw'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adamw_cifar100'

resnet_adamw_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adamw_cifar100_train_loss, resnet_adamw_cifar100_val_error = resnet_adamw_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.693240 | Validation Accuracy: 2.92% | Time elapsed: 34.32s
# Epoch 2 | Training Loss (Avg): 4.403769 | Validation Accuracy: 2.76% | Time elapsed: 33.41s
# Epoch 3 | Training Loss (Avg): 4.386625 | Validation Accuracy: 2.3% | Time elapsed: 33.18s
# Epoch 4 | Training Loss (Avg): 4.351739 | Validation Accuracy: 2.3% | Time elapsed: 33.74s
# Epoch 5 | Training Loss (Avg): 4.428181 | Validation Accuracy: 2.02% | Time elapsed: 33.47s
# Epoch 6 | Training Loss (Avg): 4.354566 | Validation Accuracy: 3.1% | Time elapsed: 34.46s
# Epoch 7 | Training Loss (Avg): 4.320664 | Validation Accuracy: 3.0% | Time elapsed: 34.26s
# Epoch 8 | Training Loss (Avg): 4.298443 | Validation Accuracy: 2.88% | Time elapsed: 34.82s
# Epoch 9 | Training Loss (Avg): 4.285512 | Validation Accuracy: 2.5% | Time elapsed: 33.13s
# Epoch 10 | Training Loss (Avg): 4.277045 | Validation Accuracy: 2.92% | Time elapsed: 34.31s
# ...

# %%
resnet_adamw_cifar100.test()
# Out:
# Accuracy of the model on test images: 3.0%

# %% [markdown]
# # Adamw, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adamw'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adamw_cifar100'

vgg_adamw_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adamw_cifar100_train_loss, vgg_adamw_cifar100_val_error = vgg_adamw_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 2386565255039915804065792.000000 | Validation Accuracy: 0.98% | Time elapsed: 78.60s
# Epoch 2 | Training Loss (Avg): 794903874095976192.000000 | Validation Accuracy: 0.84% | Time elapsed: 76.85s
# Epoch 3 | Training Loss (Avg): 9604184782765555712.000000 | Validation Accuracy: 1.04% | Time elapsed: 76.74s
# Epoch 4 | Training Loss (Avg): 353456300969652416.000000 | Validation Accuracy: 1.14% | Time elapsed: 76.89s
# Epoch 5 | Training Loss (Avg): 62677023031717632.000000 | Validation Accuracy: 0.92% | Time elapsed: 76.82s
# Epoch 6 | Training Loss (Avg): 27160906116710272.000000 | Validation Accuracy: 0.94% | Time elapsed: 76.68s
# Epoch 7 | Training Loss (Avg): 8194783265894921.000000 | Validation Accuracy: 0.84% | Time elapsed: 76.77s
# Epoch 8 | Training Loss (Avg): 1075617113714044.875000 | Validation Accuracy: 1.1% | Time elapsed: 76.78s
# Epoch 9 | Training Loss (Avg): 137413741525561.906250 | Validation Accuracy: 1.14% | Time elapsed: 76.75s
# ...

# %%
vgg_adamw_cifar100.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # Adamw, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adamw'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adamw_cifar100'

wideresnet_adamw_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adamw_cifar100_train_loss, wideresnet_adamw_cifar100_val_error = wideresnet_adamw_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 5.473150 | Validation Accuracy: 0.94% | Time elapsed: 89.29s
# Epoch 2 | Training Loss (Avg): 4.691487 | Validation Accuracy: 0.86% | Time elapsed: 86.69s
# Epoch 3 | Training Loss (Avg): 4.672816 | Validation Accuracy: 0.96% | Time elapsed: 85.82s
# Epoch 4 | Training Loss (Avg): 4.649917 | Validation Accuracy: 0.88% | Time elapsed: 86.43s
# Epoch 5 | Training Loss (Avg): 4.650884 | Validation Accuracy: 0.98% | Time elapsed: 85.95s
# Epoch 6 | Training Loss (Avg): 4.650284 | Validation Accuracy: 0.84% | Time elapsed: 86.00s
# Epoch 7 | Training Loss (Avg): 4.648807 | Validation Accuracy: 0.78% | Time elapsed: 85.89s
# Epoch 8 | Training Loss (Avg): 4.648173 | Validation Accuracy: 0.78% | Time elapsed: 86.39s
# Epoch 9 | Training Loss (Avg): 4.649941 | Validation Accuracy: 1.06% | Time elapsed: 85.90s
# Epoch 10 | Training Loss (Avg): 4.650217 | Validation Accuracy: 1.24% | Time elapsed: 86.57s
# ...

# %%
wideresnet_adamw_cifar100.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # NAdam, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'nadam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_nadam_cifar100'

resnet_nadam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_nadam_cifar100_train_loss, resnet_nadam_cifar100_val_error = resnet_nadam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.739510 | Validation Accuracy: 1.66% | Time elapsed: 33.27s
# Epoch 2 | Training Loss (Avg): 4.686669 | Validation Accuracy: 1.38% | Time elapsed: 32.38s
# Epoch 3 | Training Loss (Avg): 4.975116 | Validation Accuracy: 1.32% | Time elapsed: 32.82s
# Epoch 4 | Training Loss (Avg): 4.852655 | Validation Accuracy: 1.08% | Time elapsed: 32.70s
# Epoch 5 | Training Loss (Avg): 4.842621 | Validation Accuracy: 0.96% | Time elapsed: 32.73s
# Epoch 6 | Training Loss (Avg): 4.827468 | Validation Accuracy: 0.82% | Time elapsed: 32.70s
# Epoch 7 | Training Loss (Avg): 4.857030 | Validation Accuracy: 1.02% | Time elapsed: 32.22s
# Epoch 8 | Training Loss (Avg): 4.857055 | Validation Accuracy: 1.3% | Time elapsed: 32.92s
# Epoch 9 | Training Loss (Avg): 4.827475 | Validation Accuracy: 0.8% | Time elapsed: 32.88s
# Epoch 10 | Training Loss (Avg): 4.833700 | Validation Accuracy: 0.74% | Time elapsed: 32.66s
# ...

# %%
resnet_nadam_cifar100.test()
# Out:
# Accuracy of the model on test images: 27.0%

# %% [markdown]
# # NAdam, VGG

# %%
model_type = 'vgg'
optimizer_type = 'nadam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_nadam_cifar10'

vgg_nadam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_nadam_cifar100_train_loss, vgg_nadam_cifar100_val_error = vgg_nadam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4839098314510008582144.000000 | Validation Accuracy: 1.32% | Time elapsed: 86.06s
# Epoch 2 | Training Loss (Avg): 34.005421 | Validation Accuracy: 1.0% | Time elapsed: 86.00s
# Epoch 3 | Training Loss (Avg): 12.646771 | Validation Accuracy: 1.0% | Time elapsed: 85.91s
# Epoch 4 | Training Loss (Avg): 7.233042 | Validation Accuracy: 0.94% | Time elapsed: 85.94s
# Epoch 5 | Training Loss (Avg): 7.048641 | Validation Accuracy: 1.2% | Time elapsed: 85.89s
# Epoch 6 | Training Loss (Avg): 6.503227 | Validation Accuracy: 0.86% | Time elapsed: 85.90s
# Epoch 7 | Training Loss (Avg): 5.526616 | Validation Accuracy: 1.0% | Time elapsed: 86.02s
# Epoch 8 | Training Loss (Avg): 7.389888 | Validation Accuracy: 0.86% | Time elapsed: 85.89s
# Epoch 9 | Training Loss (Avg): 4.904248 | Validation Accuracy: 1.04% | Time elapsed: 85.92s
# Epoch 10 | Training Loss (Avg): 25.498824 | Validation Accuracy: 0.74% | Time elapsed: 85.87s
# ...

# %%
vgg_nadam_cifar100.test()
# Out:
# Accuracy of the model on test images: 0.0%

# %% [markdown]
# # NAdam, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'nadam'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_nadam_cifar100'

wideresnet_nadam_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_nadam_cifar100_train_loss, wideresnet_nadam_cifar100_val_error = wideresnet_nadam_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 6.175438 | Validation Accuracy: 1.08% | Time elapsed: 92.33s
# Epoch 2 | Training Loss (Avg): 5.571880 | Validation Accuracy: 0.96% | Time elapsed: 92.57s
# Epoch 3 | Training Loss (Avg): 5.586124 | Validation Accuracy: 0.98% | Time elapsed: 92.43s
# Epoch 4 | Training Loss (Avg): 5.224897 | Validation Accuracy: 1.06% | Time elapsed: 92.35s
# Epoch 5 | Training Loss (Avg): 5.185036 | Validation Accuracy: 0.74% | Time elapsed: 91.42s
# Epoch 6 | Training Loss (Avg): 5.191656 | Validation Accuracy: 1.08% | Time elapsed: 91.35s
# Epoch 7 | Training Loss (Avg): 6.241077 | Validation Accuracy: 1.08% | Time elapsed: 92.11s
# Epoch 8 | Training Loss (Avg): 5.959825 | Validation Accuracy: 1.16% | Time elapsed: 91.77s
# Epoch 9 | Training Loss (Avg): 5.875530 | Validation Accuracy: 0.92% | Time elapsed: 91.30s
# Epoch 10 | Training Loss (Avg): 5.731682 | Validation Accuracy: 0.8% | Time elapsed: 90.73s
# ...

# %%
wideresnet_nadam_cifar100.test()
# Out:
# Accuracy of the model on test images: 10.0%

# %% [markdown]
# # Adadelta, Resnet

# %%
model_type = 'resnet'
optimizer_type = 'adadelta'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'resnet_adadelta_cifar100'

resnet_adadelta_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
resnet_adadelta_cifar100_train_loss, resnet_adadelta_cifar100_val_error = resnet_adadelta_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 3.778780 | Validation Accuracy: 21.5% | Time elapsed: 40.32s
# Epoch 2 | Training Loss (Avg): 2.982145 | Validation Accuracy: 27.52% | Time elapsed: 37.53s
# Epoch 3 | Training Loss (Avg): 2.585800 | Validation Accuracy: 32.5% | Time elapsed: 38.03s
# Epoch 4 | Training Loss (Avg): 2.292311 | Validation Accuracy: 34.92% | Time elapsed: 37.03s
# Epoch 5 | Training Loss (Avg): 2.049238 | Validation Accuracy: 38.14% | Time elapsed: 36.25s
# Epoch 6 | Training Loss (Avg): 1.809048 | Validation Accuracy: 39.58% | Time elapsed: 36.70s
# Epoch 7 | Training Loss (Avg): 1.585325 | Validation Accuracy: 40.02% | Time elapsed: 36.68s
# Epoch 8 | Training Loss (Avg): 1.365557 | Validation Accuracy: 39.2% | Time elapsed: 36.38s
# Epoch 9 | Training Loss (Avg): 1.168597 | Validation Accuracy: 38.22% | Time elapsed: 36.02s
# Epoch 10 | Training Loss (Avg): 0.991792 | Validation Accuracy: 39.0% | Time elapsed: 37.08s
# ...

# %%
resnet_adadelta_cifar100.test()
# Out:
# Accuracy of the model on test images: 44.0%

# %% [markdown]
# # Adadelta, VGG

# %%
model_type = 'vgg'
optimizer_type = 'adadelta'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'vgg_adadelta_cifar100'

vgg_adadelta_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
# ...

# %%
vgg_adadelta_cifar100_train_loss, vgg_adadelta_cifar100_val_error = vgg_adadelta_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.854406 | Validation Accuracy: 1.02% | Time elapsed: 100.64s
# Epoch 2 | Training Loss (Avg): 4.700869 | Validation Accuracy: 0.94% | Time elapsed: 93.57s
# Epoch 3 | Training Loss (Avg): 4.675234 | Validation Accuracy: 1.06% | Time elapsed: 92.66s
# Epoch 4 | Training Loss (Avg): 4.671939 | Validation Accuracy: 1.04% | Time elapsed: 92.64s
# Epoch 5 | Training Loss (Avg): 4.672029 | Validation Accuracy: 0.98% | Time elapsed: 92.44s
# Epoch 6 | Training Loss (Avg): 4.669917 | Validation Accuracy: 1.1% | Time elapsed: 92.29s
# Epoch 7 | Training Loss (Avg): 4.673222 | Validation Accuracy: 1.06% | Time elapsed: 92.47s
# Epoch 8 | Training Loss (Avg): 4.674417 | Validation Accuracy: 1.04% | Time elapsed: 92.40s
# Epoch 9 | Training Loss (Avg): 4.674245 | Validation Accuracy: 1.1% | Time elapsed: 92.38s
# Epoch 10 | Training Loss (Avg): 4.676482 | Validation Accuracy: 0.86% | Time elapsed: 92.15s
# ...

# %%
vgg_adadelta_cifar100.test()
# Out:
# Accuracy of the model on test images: 1.0%

# %% [markdown]
# # Adadelta, Wideresnet

# %%
model_type = 'wideresnet'
optimizer_type = 'adadelta'
dataset = 'cifar100'
train_val_split = 0.9
batch_size = 32
epochs = 100
learning_rate = 0.1
momentum = 0.9
p = 1/8
weight_decay = 5e-4
beta1 = 0.9
beta2 = 0.999
lr_scheduler_milestones = [40, 80]
lr_scheduler_gamma = 0.1
save_folder = 'wideresnet_adadelta_cifar100'

wideresnet_adadelta_cifar100 = Model(model_type = model_type,
            optimizer_type = optimizer_type,
            dataset = dataset,
            train_val_split = train_val_split,
            batch_size = batch_size,
            epochs = epochs,
            learning_rate = learning_rate,
            momentum = momentum,
            p = p,
            weight_decay = weight_decay,
            beta1 = beta1,
            beta2 = beta2,
            lr_scheduler_milestones = lr_scheduler_milestones,
            lr_scheduler_gamma = lr_scheduler_gamma,
            save_folder = save_folder)
# Out:
# Preparing the dataset.
# Files already downloaded and verified
# Files already downloaded and verified
#
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
wideresnet_adadelta_cifar100_train_loss, wideresnet_adadelta_cifar100_val_error = wideresnet_adadelta_cifar100.train()
# Out:
# Epoch 1 | Training Loss (Avg): 4.145848 | Validation Accuracy: 15.24% | Time elapsed: 99.50s
# Epoch 2 | Training Loss (Avg): 3.323336 | Validation Accuracy: 24.68% | Time elapsed: 98.51s
# Epoch 3 | Training Loss (Avg): 2.847849 | Validation Accuracy: 29.74% | Time elapsed: 99.13s
# Epoch 4 | Training Loss (Avg): 2.499745 | Validation Accuracy: 29.3% | Time elapsed: 98.38s
# Epoch 5 | Training Loss (Avg): 2.212641 | Validation Accuracy: 31.88% | Time elapsed: 98.48s
# Epoch 6 | Training Loss (Avg): 1.938797 | Validation Accuracy: 35.62% | Time elapsed: 98.38s
# Epoch 7 | Training Loss (Avg): 1.717473 | Validation Accuracy: 29.92% | Time elapsed: 98.62s
# Epoch 8 | Training Loss (Avg): 1.477803 | Validation Accuracy: 34.14% | Time elapsed: 98.19s
# Epoch 9 | Training Loss (Avg): 1.324602 | Validation Accuracy: 34.68% | Time elapsed: 98.90s
# Epoch 10 | Training Loss (Avg): 1.150680 | Validation Accuracy: 37.9% | Time elapsed: 97.63s
# ...

# %%
wideresnet_adadelta_cifar100.test()
# Out:
# Accuracy of the model on test images: 48.0%

# %% [markdown]
# # Visualizations - Train Loss vs Epoch (for all the above Optimization algorithms and 3 model types)

# %%
plt.figure(figsize = (10, 7))
plt.title("ResNet")
plt.plot(resnet_padam_cifar100_p8_train_loss, label = 'padam')
plt.plot(resnet_sgd_cifar100_train_loss, label = 'sgd')
plt.plot(resnet_adam_cifar100_train_loss, label = 'adam')
plt.plot(resnet_adamw_cifar100_train_loss, label = 'adamw')
plt.plot(resnet_nadam_cifar100_train_loss, label = 'nadam')
plt.plot(resnet_adadelta_cifar100_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("VGG")
plt.plot(vgg_padam_cifar100_p8_train_loss, label = 'padam')
plt.plot(vgg_sgd_cifar100_train_loss, label = 'sgd')
plt.plot(vgg_adam_cifar100_train_loss, label = 'adam')
plt.plot(vgg_adamw_cifar100_train_loss, label = 'adamw')
plt.plot(vgg_nadam_cifar100_train_loss, label = 'nadam')
plt.plot(vgg_adadelta_cifar100_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("Wide-ResNet")
plt.plot(wideresnet_padam_cifar100_p8_train_loss, label = 'padam')
plt.plot(wideresnet_sgd_cifar100_train_loss, label = 'sgd')
plt.plot(wideresnet_adam_cifar100_train_loss, label = 'adam')
plt.plot(wideresnet_adamw_cifar100_train_loss, label = 'adamw')
plt.plot(wideresnet_nadam_cifar100_train_loss, label = 'nadam')
plt.plot(wideresnet_adadelta_cifar100_train_loss, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Training Loss per Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Visualizations - Train Loss vs Validation Error (for all the above Optimization algorithms and 3 model types)

# %%
plt.figure(figsize = (10, 7))
plt.title("ResNet")
plt.plot(resnet_padam_cifar100_p8_val_error, label = 'padam')
plt.plot(resnet_sgd_cifar100_val_error, label = 'sgd')
plt.plot(resnet_adam_cifar100_val_error, label = 'adam')
plt.plot(resnet_adamw_cifar100_val_error, label = 'adamw')
plt.plot(resnet_nadam_cifar100_val_error, label = 'nadam')
plt.plot(resnet_adadelta_cifar100_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("VGG")
plt.plot(vgg_padam_cifar100_p8_val_error, label = 'padam')
plt.plot(vgg_sgd_cifar100_val_error, label = 'sgd')
plt.plot(vgg_adam_cifar100_val_error, label = 'adam')
plt.plot(vgg_adamw_cifar100_val_error, label = 'adamw')
plt.plot(vgg_nadam_cifar100_val_error, label = 'nadam')
plt.plot(vgg_adadelta_cifar100_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

print("")
plt.figure(figsize = (10, 7))
plt.title("Wide-ResNet")
plt.plot(wideresnet_padam_cifar100_p8_val_error, label = 'padam')
plt.plot(wideresnet_sgd_cifar100_val_error, label = 'sgd')
plt.plot(wideresnet_adam_cifar100_val_error, label = 'adam')
plt.plot(wideresnet_adamw_cifar100_val_error, label = 'adamw')
plt.plot(wideresnet_nadam_cifar100_val_error, label = 'nadam')
plt.plot(wideresnet_adadelta_cifar100_val_error, label = 'adadelta')
plt.xlabel("Epochs")
plt.ylabel("Validation Error % per Epoch")
plt.legend(loc = "upper right")
plt.show()

# %% [markdown]
# # Validation Accuracy table for all the above algorithms and 3 model types
